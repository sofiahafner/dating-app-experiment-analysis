# %%
from IPython import display
import pandas as pd
import matplotlib.pyplot as plt
import textwrap
import ast
import glob
import os
import sacredfig
import numpy as np
plt.style.use(sacredfig.style)

# %% [markdown]
# ### Loading in filtered and structured dataframes from experiment
# (See creating_data_structures.ipynb for info on how structure was created from empirica export)

# %%
combined_path = '/Users/franziskahafner/Desktop/oii/trinity/thesis/experiment_data/prolific_data/combined_experiment_data/'
character_df = pd.read_csv(combined_path + "character_df.csv")
player_df = pd.read_csv(combined_path + "player_df.csv")
characterChoiceSurvey_df = pd.read_csv(combined_path + "characterChoiceSurvey_df.csv")
SwipeDecision_df = pd.read_csv(combined_path + "SwipeDecision_df.csv")
endRecSystemSurvey_df = pd.read_csv(combined_path + "endRecSystemSurvey_df.csv")
endDatingAppSurvey_df = pd.read_csv(combined_path + "endDatingAppSurvey_df.csv")
SwipeProfileRecSystemSurvey_df = pd.read_csv(combined_path + "SwipeProfileRecSystemSurvey_df.csv")
SwipeProfileProfileChoiceSurvey_df = pd.read_csv(combined_path + "SwipeProfileProfileChoiceSurvey_df.csv")
SwipeProfileRecSystemSurvey_df = SwipeProfileRecSystemSurvey_df.merge(SwipeDecision_df[['id', 'roundsPlayed']], on = 'id', how = 'left')

# %%
player_df[player_df['Country of residence']!='United Kingdom']
# Out:
#                             id  chosenProfile                    playerID  \
# 23  01J1PZEXHB471YMXC9EP4YB2HB           77.0  01J1PZCBVB625VHEMVH56A888Z
# 30  01J1SWGHWZVNS7RN0BTFTJXRW0          146.0  01J1SWG5W18GTVXPT379VCB63X
# 31  01J1SRS67GHFGJD3M14EW1GAFZ          170.0  01J1SRRWK4KZ7H9JJ7BNX7DJB2
# 32  01J1SV3G1H95345SP9K1C8ST5X          178.0  01J1SV38EG0TYZ7YH8YRPQ3Z7Y
# 33  01J1SVERDDBKBPEDQC58RMTHJN           40.0  01J1SVCHF9XTBH5XHRYZWP3S4J
# 34  01J1SQZ3HXZ67H9BGXMYBF8DY8           36.0  01J1SQYPJ62646PB9P4CYYDHRV
# 35  01J1ST870TD69D7CMKF4S4ADD4          242.0  01J1ST83K58Y1FY1SYX8QR2VW9
# 37  01J1SV6854TXZ3X83FJ9F7Z3S3           28.0  01J1SV2ZTS4Y0QXN6HKEE5EF66
# 38  01J1SYT1PA6PGB7NHBN2MXQJV2          147.0  01J1SYS6EA86NNVTZ8GW7ECYQV
# 39  01J1SR4S21VF65TR9CEVDMVRN3          202.0  01J1SR4BN2V07PE6SGTTJZFM3E
# 40  01J1ST3WQSM09Z3WBW4TQ9SY5D          170.0  01J1ST3K3SQX1G5QH019ZSKE6E
# 41  01J1SNSCYNZYJAZCS371N2G7YW          198.0  01J1SNS7G7CT8V0G06HD4JXXZC
# 42  01J1SSEVG9MBW5TE9N9FKJQVJB          220.0  01J1SSDYETW61BKSZTS3SHZBYS
# 43  01J1SWCSZ2NBJERP6RF62291QC           76.0  01J1SWCMAZ7NK4TPQZFWHBEPV2
# 44  01J1SPYTBXEZHCKY4669S27X8D           40.0  01J1SPYP8N3GHG3D5KQ8YB1NXN
# 45  01J1SPZ0A40P9Y5BJ8406JE9HC          193.0  01J1SPY7JVWGDCT9D72YCEZQGP
# 46  01J1STVQAJGYBBKTFMZRJ7MFYM          156.0  01J1STVJRGBHEN283PATNAJX8S
# 47  01J1SSGZRG2HYSTHCT44V0K4GZ          231.0  01J1SSGE4X8DZRY1MAYS1PZEZA
# 48  01J1STDT6ZY3G18PP6PQJ1F7FG          153.0  01J1STDQ8PV0950JFZ6A1587TE
# 49  01J1SR3TXHXAZ01J0TF2X23EFE          171.0  01J1SR3K6Q9C89M29FVB2ZSKWM
# 50  01J1SSE36F3RCKE1DMY08NEP2E          246.0  01J1SSDNNE75B5KXYP7FKDYB3D
# 59  01J1R4W749PNP1DS376GPCKFS5          215.0  01J1R4VK1EK81CRJQRRRETRX9B
#
#                           participantIdentifier recAlgorithm       ended  \
# 23  60be1ea6b06c026c3531e0f5@email.prolific.com       random  game ended
# 30                     664d031e39f59ffa82289b1a       random  game ended
# 31                     656dd46f79cd75dd0b1d8f5d       random  game ended
# 32                     665d306994d28913423b051c       random  game ended
# 33                     666b3263f7086b00ac42f9ac       random  game ended
# 34                     5de260b9553cee28d97b058d       random  game ended
# 35                     65c24c1cdbd62fdb8f54d86e       random  game ended
# 37                     665193d6eac8c50fed1b5d60       random  game ended
# 38                     610810c0356aacedc8cbc6f0       random  game ended
# 39                     5e9f2cd17c41440a2855a88e       random  game ended
# 40                     65b572d889d40cd5a85fcd61       random  game ended
# 41                     6612188353795fc3ddb6b426       random  game ended
# 42                     6678426a9e81680de1d36737       random  game ended
# 43                     59fcb4169b760100013a6363       random  game ended
# 44                     60fd11644f3b16e2483cb1e4       random  game ended
# 45                     6682599db5c9095fb8aedfb7       random  game ended
# 46                     63069f585b35a5ec752fcd30       random  game ended
# 47                     6544d1eb1020d074060bc99e       random  game ended
# 48                     65c14027646a9bbfa89584c8       random  game ended
# 49                     6638d4e576c0a53f8aa1b9e4       random  game ended
# 50                     6596c3663bd4674351a26eb8       random  game ended
# 59                     61711d5d5eeb6ccab6055d94       random  game ended
#
#                                              feedback           Status  \
# 23                                                NaN              NaN
# 30                                                NaN  AWAITING REVIEW
# 31                                                NaN  AWAITING REVIEW
# 32  Appearance mattered a lot to me, but not due t...  AWAITING REVIEW
# 33                                                NaN  AWAITING REVIEW
# 34                                                NaN  AWAITING REVIEW
# 35                                                NaN  AWAITING REVIEW
# 37                                                NaN  AWAITING REVIEW
# 38                                                NaN  AWAITING REVIEW
# 39                                                NaN  AWAITING REVIEW
# 40                                                 NO  AWAITING REVIEW
# 41                                                NaN  AWAITING REVIEW
# 42                                                NaN  AWAITING REVIEW
# 43                                                NaN  AWAITING REVIEW
# 44                                                NaN  AWAITING REVIEW
# 45                                                NaN  AWAITING REVIEW
# 46                                                NaN  AWAITING REVIEW
# 47                                                NaN  AWAITING REVIEW
# 48                                                NaN  AWAITING REVIEW
# 49                                                NaN  AWAITING REVIEW
# 50                                                NaN  AWAITING REVIEW
# 59                                        no problems  AWAITING REVIEW
#
#                      Started at                 Completed at  ...  \
# 23                          NaN                          NaN  ...
# 37             Male                Black          Nigeria
# 38           Female                White    United States
# 39           Female                White    United States
# 40           Female                White    United States
# 41             Male                White     South Africa
# 42             Male                Black          Nigeria
# 43             Male                White    United States
# 44             Male                Asian            India
# 45             Male                Mixed    United States
# 46             Male                Black    United States
# 47           Female                Black    United States
# 48           Female                Black    United States
# 49           Female                White    United States
# 50           Female                Black    United States
# 59  CONSENT_REVOKED      CONSENT_REVOKED  CONSENT_REVOKED
#
#    Country of residence      Nationality         Language   Student status  \
# 23                  NaN              NaN              NaN              NaN
# 30        United States    United States          English               No
# 31        United States    United States          English               No
# 32        United States    United States          English               No
# 33        United States    United States          English              Yes
# 34        United States    United States          English               No
# 35        United States    United States          English               No
# 37        United States          Nigeria          English     DATA_EXPIRED
# 38        United States    United States          English     DATA_EXPIRED
# 39        United States    United States          English     DATA_EXPIRED
# 40        United States    United States          English              Yes
# 41        United States     South Africa          English               No
# 42        United States    United States          English              Yes
# 43        United States    United States          English               No
# 44        United States            India           Telugu     DATA_EXPIRED
# 45        United States    United States          English               No
# 46        United States    United States          English     DATA_EXPIRED
# 47        United States    United States          English              Yes
# 48        United States    United States          English               No
# 49        United States    United States          English               No
# 50        United States    United States          English               No
# 59      CONSENT_REVOKED  CONSENT_REVOKED  CONSENT_REVOKED  CONSENT_REVOKED
#
#                                Employment status
# 23                                           NaN
# 30                                     Full-Time
# 31                                     Full-Time
# 32                  Unemployed (and job seeking)
# 33                                  DATA_EXPIRED
# 34                                     Full-Time
# 35                                     Part-Time
# 37                                     Full-Time
# 38                                  DATA_EXPIRED
# 39                                     Full-Time
# 40                                     Part-Time
# 41                                     Full-Time
# 42                                     Full-Time
# 43                  Unemployed (and job seeking)
# 44                                     Part-Time
# 45                  Unemployed (and job seeking)
# 46                                  DATA_EXPIRED
# 47                                     Full-Time
# 48                                     Full-Time
# 49  Due to start a new job within the next month
# 50                                     Full-Time
# 59                               CONSENT_REVOKED
#
# [22 rows x 22 columns]

# %% [markdown]
# ### ER-Diagram with all Data Frame names, columns, and relationships

# %%
display.Image("ER_Diagram.png")

# %%
SwipeDecision_df[SwipeDecision_df['strongPreferenceDetected']==True]
# Out:
#                               id  roundsPlayed  dislikedProfile  likedProfile  \
# 2     01J1MZ7T44SQXQ11632KMS2SX1          43.0             25.0          24.0
# 5     01J1MXTXQNMGBCTX0XRYZVYK9N          36.0            155.0         246.0
# 7     01J1MYZRP2R9METKHERM2QWDBX          24.0             15.0          75.0
# 11    01J1MXQW7KGJ1AD862S85NK7RM          25.0            172.0         213.0
# 12    01J1MZ3NPAHHEWGYVPRZFR0B8Q          31.0             19.0           0.0
# ...                          ...           ...              ...           ...
# 3535  01J1R9BQ5CFTM5MBPARBH10Z8R          37.0            248.0          53.0
# 3540  01J1R7CSGJ15J6ZPCR9A1XDJ85          35.0             82.0           2.0
# 3542  01J1R3FA8GCEA4X58W7SGV5B74          18.0            112.0         231.0
# 3547  01J1R457NW2CRP1K10MEQMWDGT          21.0            178.0         248.0
# 3549  01J1R4KJFAM7DQ6994ZPA00DHS          43.0            254.0         179.0
#
#      strongPreferenceDetected       strongPreferences  \
# 2                        True   ["beard","shortHair"]
# 5                        True             ["noBeard"]
# 7                        True   ["beard","shortHair"]
# 11                       True             ["noBeard"]
# 12                       True   ["beard","shortHair"]
# ...                       ...                     ...
# 3535                     True            ["longHair"]
# 3540                     True               ["beard"]
# 3542                     True            ["longHair"]
# 3547                     True  ["noBeard","longHair"]
# 3549                     True             ["noBeard"]
#
#                          batchID                      gameID  \
# 2     01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 5     01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0C0GYCD4B6343VXN1J
# 7     01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 11    01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0C0GYCD4B6343VXN1J
# 12    01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# ...                          ...                         ...
# 3535  01J1R2GFZA9PWFJ7ZYRQXM0AHA  01J1R2GG3DJ3KD5ZRKCRRB2WG4
# 3540  01J1R2GFZA9PWFJ7ZYRQXM0AHA  01J1R2GG1XCW2RQDPTEFHP27JC
# 3542  01J1R2GFZA9PWFJ7ZYRQXM0AHA  01J1R2GG20CNG1PGZC283FBNM2
# 3547  01J1R2GFZA9PWFJ7ZYRQXM0AHA  01J1R2GG2KS2FQPPMF04R9C880
# 3549  01J1R2GFZA9PWFJ7ZYRQXM0AHA  01J1R2GG30QD14RX5G6KXB76YG
#
#                         playerID                     roundID
# 2     01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 5     01J1MXES8XXA75N1VN97GMS1CM  01J1MXFHTEJAS93G2NANYE3KKE
# 7     01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 11    01J1MXES8XXA75N1VN97GMS1CM  01J1MXFHTEJAS93G2NANYE3KKE
# 12    01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# ...                          ...                         ...
# 3535  01J1R939DN6B6C0PCDR34A2GRW  01J1R93GKFFRW3QK425KEKJEFD
# 3540  01J1R6VPC3EWGGJV8ZF94GJG68  01J1R6VTK21TGDRM72J4WAJ7BQ
# 3542  01J1R37J3PWJSS835J53AJ0KMS  01J1R37MJMBPVCFGR8BRQ5N1JT
# 3547  01J1R3TBS2CD61Y2RM8KH61CQ1  01J1R3TMB52AV514BC2SYS47RA
# 3549  01J1R45WFBCTGQGERDGBRSFA94  01J1R46ABTH8JRZXWXYJYS7TVP
#
# [1674 rows x 10 columns]

# %%
def count_preferences(pref_string):
    if pd.isna(pref_string):
        return np.nan
    try:
        preferences = ast.literal_eval(pref_string)
        return len(preferences)
    except (ValueError, SyntaxError):
        return np.nan

SwipeDecision_df['number_of_strong_preferences'] = SwipeDecision_df['strongPreferences'].apply(count_preferences)

# %%
all_profiles = pd.concat([SwipeDecision_df[['playerID', 'likedProfile']].rename(columns={'likedProfile': 'profileID'}),
                          SwipeDecision_df[['playerID', 'dislikedProfile']].rename(columns={'dislikedProfile': 'profileID'})])

profile_counts = all_profiles.groupby(['playerID', 'profileID']).size().reset_index(name='count')

players_with_duplicates = profile_counts[profile_counts['count'] > 1]['playerID'].unique()

players_with_duplicates = list(players_with_duplicates)
players_with_duplicates
# Out:
# ['01J1MXWRPDKMVSBEHHDPDBQZAV',
#  '01J1PZCTHQP71S434SW06PWCCY',
#  '01J1PZDJE0YJWR9RH12EC3F8JE',
#  '01J1Q1A8S8G25PS4DTFM46W2BF',
#  '01J1Q1F6GS9M6QCT06XWSPMJ8T',
#  '01J1R3F4MR06WX0ZNT92Y9CXT7',
#  '01J1R3TBS2CD61Y2RM8KH61CQ1',
#  '01J1R4MEAV5ED9AX1K3FJRV7ZN',
#  '01J1R4SDN425RPYBE2ZDNBVA8Z',
#  '01J1R6VPC3EWGGJV8ZF94GJG68',
#  '01J1R895W01YV6P2SPGDXT7RGB',
#  '01J1R8HZZAVJ26V60K6EP40NFZ',
# 215                     True  ["beard","shortHair"]
# 218                     True  ["beard","shortHair"]
# 232                     True  ["beard","shortHair"]
# 237                     True  ["beard","shortHair"]
# 244                      NaN                    NaN
# 246                     True  ["beard","shortHair"]
# 251                     True  ["beard","shortHair"]
# 252                     True  ["beard","shortHair"]
# 259                     True  ["beard","shortHair"]
# 271                     True  ["beard","shortHair"]
# 281                     True  ["beard","shortHair"]
# 290                     True  ["beard","shortHair"]
# 302                     True  ["beard","shortHair"]
# 310                     True  ["beard","shortHair"]
# 321                     True  ["beard","shortHair"]
# 329                      NaN                    NaN
# 337                      NaN                    NaN
# 338                     True  ["beard","shortHair"]
# 381                     True  ["beard","shortHair"]
# 399                     True  ["beard","shortHair"]
# 400                     True  ["beard","shortHair"]
# 404                      NaN                    NaN
# 435                      NaN                    NaN
# 441                     True  ["beard","shortHair"]
# 449                     True  ["beard","shortHair"]
# 465                     True  ["beard","shortHair"]
# 468                      NaN                    NaN
# 479                     True  ["beard","shortHair"]
# 480                      NaN                    NaN
# 499                     True  ["beard","shortHair"]
#
#                         batchID                      gameID  \
# 1    01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 2    01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 6    01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 7    01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 12   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 13   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 31   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 34   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 38   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 70   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 71   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 88   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 149  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 157  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 160  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 165  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 175  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 180  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 190  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 200  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 215  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 218  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 232  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 237  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 244  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 246  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 251  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 252  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 259  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 271  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 281  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 290  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 302  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 310  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 321  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 329  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 337  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 338  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 381  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 399  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 400  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 404  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 435  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 441  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 449  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 465  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 468  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 479  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 480  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 499  01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
#
#                        playerID                     roundID  \
# 1    01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 2    01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 6    01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 7    01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 12   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 13   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 31   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 34   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 38   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 70   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 71   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 88   01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 149  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 157  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 160  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 165  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 175  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 180  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 190  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 200  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 215  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 218  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 232  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 237  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 244  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 246  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 251  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 252  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 259  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 271  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 281  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 290  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 302  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 310  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 321  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 329  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 337  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 338  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 381  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 399  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 400  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 404  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 435  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 441  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 449  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 465  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 468  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 479  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 480  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
# 499  01J1MXWRPDKMVSBEHHDPDBQZAV  01J1MXYJTSXVE19Y1P9MBRDYTE
#
#      number_of_strong_preferences
# 1                             NaN
# 2                             2.0
# 6                             NaN
# 7                             2.0
# 12                            2.0
# 13                            2.0
# 31                            NaN
# 34                            NaN
# 38                            2.0
# 70                            NaN
# 71                            2.0
# 88                            2.0
# 149                           NaN
# 157                           2.0
# 160                           NaN
# 165                           2.0
# 175                           2.0
# 180                           2.0
# 190                           2.0
# 200                           NaN
# 215                           2.0
# 218                           2.0
# 232                           2.0
# 237                           2.0
# 244                           NaN
# 246                           2.0
# 251                           2.0
# 252                           2.0
# 259                           2.0
# 271                           2.0
# 281                           2.0
# 290                           2.0
# 302                           2.0
# 310                           2.0
# 321                           2.0
# 329                           NaN
# 337                           NaN
# 338                           2.0
# 381                           2.0
# 399                           2.0
# 400                           2.0
# 404                           NaN
# 435                           NaN
# 441                           2.0
# 449                           2.0
# 465                           2.0
# 468                           NaN
# 479                           2.0
# 480                           NaN
# 499                           2.0

# %%
list(endRecSystemSurvey_df[endRecSystemSurvey_df['additionalComments'].notna()]['additionalComments'])
# Out:
# ['The recommendations seemed random, sometimes it felt like it is improving but then it would feel very random again.',
#  'No',
#  'Each time was inconsistent based on the hobbies',
#  'It was a bit hit or miss, I purposefully selected profiles with similar hobbies to mine and sometimes it would suggest people with the same hobbies but sometimes it would be something completely random. Same with age and appearance ',
#  'no',
#  'NO',
#  'nice one ',
#  'n/a this was fun!',
#  'Good luck on your research! This was fun!',
#  'love it. thanks',
#  'Whether or not the characters looked like pleasant people with smiles felt really important, and was always a tie-breaker if I was unsure... and more important than a good similarities match, if the more similar person looked angry or unhappy. ',
#  'I found the choices interesting and very varied',
#  'The age range was good it seemed to learn that quickly. The appearance was odd and I would have rejected mostly all of them based on appearance alone had I been able to do so. ',
#  'I feel the algorithm would have done better.',
#  'It needs more tweaking. ',
#  'Enjoyed taking part, the study was smooth with no issues. Maybe in the furture more options for the customization of our character which would give more detailed results.',
#  'In some stages it seemed to be learning somewhat, but I did go into the experiment with a notion of "wanting" to find a fit that more closely matched age/hobbies. Some stages recommended a string of characters that seemed to "fit" somewhat more, although most stages did feel quite random in their recommendations.',
#  'Love the artwork!',
#  'last 10 or so profiles were all the same two profiles']

# %%
endRecSystemSurvey_df
# Out:
#                             id  \
# 0   01J1MXGMAQFS5S456T86K1RR0J
# 1   01J1MZ9M1FX5RX38MR1FVCEVD4
# 2   01J1MX7NCN2SBE4N134P0GBFQJ
# 3   01J1MXXJQNKS3FP5CHME8B4ZV6
# 4   01J1MYF6XE9ZCVX6DZ89XF6MA7
# 5   01J1MYTXVZT96GB937ZSM0MYPM
# 6   01J1MWNJ42E4864PK859T1BQYT
# 7   01J1MWWC5NQRDQ2329JPXWCAXM
# 8   01J1MXM1BNZTJ7NX9B7K4A44FR
# 9   01J1MX834GMRH22FQ6DXR6S4MG
# 10  01J1Q0995VNVB9BPNKMCFV6XRW
# 11  01J1Q1SWK8YKRZ7JD3WXPEANZN
# 12  01J1PZSG4JD987FY01NTEZATS7
# 13  01J1Q130MWBGY8YWBVDT81CB7F
# 14  01J1Q27N7NR2XA2W8YYQ10YWYB
# 15  01J1Q0NP9K7048TA5V0KFDRX6C
# 16  01J1Q1B556N9E7AVGDNYNJ1GY0
# 17  01J1Q1JR0720XXADJKWRBZN0E0
# 18  01J1Q1VVH2X2ST4R3KQ5WJWAFJ
# 19  01J1Q0WF13BY40BWKWTHZCP5F5
# 20  01J1Q106W0ZYWTD9CPKMKQEVNM
# 21  01J1PZTF2CX4JWCNWP1648M0HX
# 22  01J1Q2JMB0A4QV0DX4ANS07ZKT
# 23  01J1Q2A2H1HPNB8K71FVKRF714
# 24  01J1Q0BHMS8SX01FC9DEWT7J2V
# 25  01J1PZJY73JZYSTA3MA5TAK6FQ
# 26  01J1Q1N90A5S8RP9JWBAQP4CY8
# 27  01J1Q2A4GB2N05518B22A22FPB
# 28  01J1PZPND7187X7BXMGC5GZFY4
# 29  01J1Q19HK087SSQ69EXDFADQ61
# 30  01J1R7GXEQXM983N4F5KT3N9EC
# 31  01J1R4NB8JA4K1E0H177R8G50X
# 32  01J1R5XRBXWCSYT4MA5NM64C90
# 33  01J1R3WC9YE9W9RQ3DSSN6EC7D
# 34  01J1R5976VTRMF4DHX9ZAJ8GHZ
# 35  01J1R8QHX447092Y368V0ZFC4K
# 36  01J1R9ZCB2FKSSQ0MQ4AQGEZH0
# 37  01J1R4BTYPQ88GDHWNXNJBVM0H
# 38  01J1R938SG0H67NM3X4HRFKT2E
# 39  01J1R5VYH5KCRZ4MZ0S995EW1H
# 40  01J1R3ZNZK8YF14YHDG4KKQE8V
# 41  01J1R54HV0AH8T7NMKSTRKH547
# 42  01J1R3NEKAEAEM3P4H95BASZG8
# 43  01J1R4S6P2HBS4AVHZPSRQGKSE
# 44  01J1R9DTTJ9TXHSZNW81JTWYFV
# 45  01J1R5GM8KSK9EHTA239FDM791
# 46  01J1R4FA1PGSN48JSRWABT9DCT
# 47  01J1R4FAN8GHVK373BVKVE8E3V
# 48  01J1RARMZBZJW9PDY50S207WTQ
# 49  01J1R57634BX3HVRMKA91SBVFA
#
#                                    additionalComments  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  The recommendations seemed random, sometimes i...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                 No
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25    Each time was inconsistent based on the hobbies
# 26  It was a bit hit or miss, I purposefully selec...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30    I found the choices interesting and very varied
# 31                                                NaN
# 32  The age range was good it seemed to learn that...
# 33       I feel the algorithm would have done better.
# 34                           It needs more tweaking.
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38  Enjoyed taking part, the study was smooth with...
# 39  In some stages it seemed to be learning somewh...
# 40                                                NaN
# 41                                  Love the artwork!
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47  last 10 or so profiles were all the same two p...
# 48                                                NaN
# 49                                                NaN
#
#                                       algorithmChoice  \
# 0   An algorithm that learned your preferences and...
# 1   An algorithm that provided random profile reco...
# 2   An algorithm that learned your preferences and...
# 3   An algorithm that learned your preferences and...
# 4   An algorithm that provided random profile reco...
# 5   An algorithm that learned your preferences and...
# 6   An algorithm that learned your preferences and...
# 7   An algorithm that learned your preferences and...
# 8   An algorithm that provided random profile reco...
# 9   An algorithm that learned your preferences and...
# 10  An algorithm that provided random profile reco...
# 11  An algorithm that learned your preferences and...
# 12  An algorithm that provided random profile reco...
# 13  An algorithm that provided random profile reco...
# 14  An algorithm that learned your preferences and...
# 15  An algorithm that provided random profile reco...
# 16  An algorithm that provided random profile reco...
# 17  An algorithm that provided random profile reco...
# 18  An algorithm that learned your preferences and...
# 19  An algorithm that ranked profiles based on the...
# 20  An algorithm that provided random profile reco...
# 21  An algorithm that learned your preferences and...
# 22  An algorithm that learned your preferences and...
# 23  An algorithm that provided random profile reco...
# 24  An algorithm that learned your preferences and...
# 25  An algorithm that provided random profile reco...
# 26  An algorithm that learned your preferences and...
# 27  An algorithm that provided random profile reco...
# 28  An algorithm that provided random profile reco...
# 29  An algorithm that ranked profiles based on the...
# 30  An algorithm that learned your preferences and...
# 31  An algorithm that learned your preferences and...
# 32  An algorithm that learned your preferences and...
# 33  An algorithm that learned your preferences and...
# 34  An algorithm that ranked profiles based on the...
# 35  An algorithm that learned your preferences and...
# 36  An algorithm that provided random profile reco...
# 37  An algorithm that learned your preferences and...
# 38  An algorithm that learned your preferences and...
# 39  An algorithm that provided random profile reco...
# 40  An algorithm that learned your preferences and...
# 41  An algorithm that ranked profiles based on the...
# 42  An algorithm that provided random profile reco...
# 43  An algorithm that provided random profile reco...
# 44  An algorithm that learned your preferences and...
# 45  An algorithm that ranked profiles based on the...
# 46  An algorithm that provided random profile reco...
# 47  An algorithm that provided random profile reco...
# 48  An algorithm that learned your preferences and...
# 49  An algorithm that learned your preferences and...
#
#    algorithmLearntAttribute-Age algorithmLearntAttribute-Appearance  \
# 0                Learned slowly                       Did not learn
# 1                 Did not learn                       Did not learn
# 2                Learned slowly                      Learned slowly
# 3                Learned slowly                      Learned slowly
# 4                 Did not learn                       Did not learn
# 5               Learned quickly                      Learned slowly
# 6                Learned slowly                      Learned slowly
# 7                 Did not learn                       Did not learn
# 8                 Did not learn                       Did not learn
# 9               Learned quickly                      Learned slowly
# 10              Learned quickly                      Learned slowly
# 11              Learned quickly                       Did not learn
# 12                Did not learn                       Did not learn
# 13               Learned slowly                       Did not learn
# 14               Learned slowly                      Learned slowly
# 15                Did not learn                       Did not learn
# 16                Did not learn                       Did not learn
# 17               Learned slowly                       Did not learn
# 18              Learned quickly                      Learned slowly
# 19              Learned quickly                      Learned slowly
# 20                Did not learn                      Learned slowly
# 21               Learned slowly                      Learned slowly
# 22                Did not learn                       Did not learn
# 23               Learned slowly                      Learned slowly
# 24                Did not learn                       Did not learn
# 25               Learned slowly                       Did not learn
# 26              Learned quickly                      Learned slowly
# 27              Learned quickly                      Learned slowly
# 28                Did not learn                       Did not learn
# 29               Learned slowly                      Learned slowly
# 30               Learned slowly                      Learned slowly
# 31              Learned quickly                      Learned slowly
# 32              Learned quickly                       Did not learn
# 33              Learned quickly                     Learned quickly
# 34                Did not learn                       Did not learn
# 35               Learned slowly                     Learned quickly
# 36                Did not learn                       Did not learn
# 37                Did not learn                     Learned quickly
# 38              Learned quickly                       Did not learn
# 39                Did not learn                       Did not learn
# 40               Learned slowly                       Did not learn
# 41                Did not learn                       Did not learn
# 42               Learned slowly                       Did not learn
# 43                Did not learn                       Did not learn
# 44               Learned slowly                       Did not learn
# 45              Learned quickly                      Learned slowly
# 46               Learned slowly                       Did not learn
# 47              Learned quickly                       Did not learn
# 48               Learned slowly                      Learned slowly
# 49                Did not learn                      Learned slowly
#
#    algorithmLearntAttribute-Hobbies algorithmLearntAttribute-Job  \
# 0                    Learned slowly               Learned slowly
# 1                    Learned slowly                Did not learn
# 2                    Learned slowly               Learned slowly
# 3                   Learned quickly              Learned quickly
# 4                     Did not learn                Did not learn
# 5                   Learned quickly              Learned quickly
# 6                   Learned quickly              Learned quickly
# 7                    Learned slowly              Learned quickly
# 8                   Learned quickly               Learned slowly
# 9                    Learned slowly              Learned quickly
# 10                   Learned slowly                Did not learn
# 11                  Learned quickly               Learned slowly
# 12                    Did not learn                Did not learn
# 13                    Did not learn               Learned slowly
# 14                  Learned quickly               Learned slowly
# 15                    Did not learn                Did not learn
# 16                   Learned slowly                Did not learn
# 17                    Did not learn               Learned slowly
# 18                   Learned slowly              Learned quickly
# 19                    Did not learn                Did not learn
# 20                   Learned slowly              Learned quickly
# 21                   Learned slowly              Learned quickly
# 22                   Learned slowly                Did not learn
# 23                   Learned slowly               Learned slowly
# 24                  Learned quickly              Learned quickly
# 25                  Learned quickly                Did not learn
# 26                  Learned quickly                Did not learn
# 27                    Did not learn              Learned quickly
# 28                    Did not learn                Did not learn
# 29                    Did not learn               Learned slowly
# 30                  Learned quickly              Learned quickly
# 31                   Learned slowly               Learned slowly
# 32                  Learned quickly               Learned slowly
# 33                   Learned slowly                Did not learn
# 34                    Did not learn               Learned slowly
# 35                    Did not learn                Did not learn
# 36                   Learned slowly                Did not learn
# 37                   Learned slowly                Did not learn
# 38                  Learned quickly               Learned slowly
# 39                   Learned slowly                Did not learn
# 40                   Learned slowly               Learned slowly
# 41                   Learned slowly               Learned slowly
# 42                   Learned slowly                Did not learn
# 43                    Did not learn                Did not learn
# 44                   Learned slowly                Did not learn
# 45                  Learned quickly              Learned quickly
# 46                    Did not learn               Learned slowly
# 47                   Learned slowly               Learned slowly
# 48                  Learned quickly              Learned quickly
# 49                  Learned quickly              Learned quickly
#
#                               recommendationDiversity  \
# 0   The recommendations were too similar and lacke...
# 1   The recommendations were too varied and incons...
# 2   The recommendations were too varied and incons...
# 3   The diversity of recommendations was balanced ...
# 4   The diversity of recommendations was balanced ...
# 5   The diversity of recommendations was balanced ...
# 6   The diversity of recommendations was balanced ...
# 7   The recommendations were too varied and incons...
# 8   The recommendations were too varied and incons...
# 9   The recommendations were too varied and incons...
# 10  The diversity of recommendations was balanced ...
# 11  The diversity of recommendations was balanced ...
# 12  The diversity of recommendations was balanced ...
# 13  The recommendations were too similar and lacke...
# 14  The diversity of recommendations was balanced ...
# 15  The recommendations were too similar and lacke...
# 16  The recommendations were too varied and incons...
# 17  The recommendations were too varied and incons...
# 18  The diversity of recommendations was balanced ...
# 19  The recommendations were too varied and incons...
# 20  The recommendations were too varied and incons...
# 21  The diversity of recommendations was balanced ...
# 22  The diversity of recommendations was balanced ...
# 23  The recommendations were too varied and incons...
# 24  The diversity of recommendations was balanced ...
# 25  The recommendations were too similar and lacke...
# 26  The recommendations were too varied and incons...
# 27  The diversity of recommendations was balanced ...
# 28  The recommendations were too varied and incons...
# 29  The recommendations were too similar and lacke...
# 30  The diversity of recommendations was balanced ...
# 31  The recommendations were too varied and incons...
# 32  The recommendations were too varied and incons...
# 33  The diversity of recommendations was balanced ...
# 34  The recommendations were too similar and lacke...
# 35  The recommendations were too varied and incons...
# 36  The recommendations were too varied and incons...
# 37  The recommendations were too varied and incons...
# 38  The recommendations were too varied and incons...
# 39  The recommendations were too varied and incons...
# 40  The recommendations were too similar and lacke...
# 41  The diversity of recommendations was balanced ...
# 42  The recommendations were too similar and lacke...
# 43  The recommendations were too similar and lacke...
# 44  The recommendations were too varied and incons...
# 45  The diversity of recommendations was balanced ...
# 46  The recommendations were too varied and incons...
# 47  The recommendations were too varied and incons...
# 48  The recommendations were too varied and incons...
# 49  The recommendations were too varied and incons...
#
#                                 recommendationQuality  \
# 0   Some recommendations were good, and some not s...
# 1   Some recommendations were good, and some not s...
# 2   Some recommendations were good, and some not s...
# 3   Some recommendations were good, and some not s...
# 4   Some recommendations were good, and some not s...
# 5             All/most recommendations were very good
# 6   Some recommendations were good, and some not s...
# 7                   All/most recommendations were bad
# 8   Some recommendations were good, and some not s...
# 9   Some recommendations were good, and some not s...
# 10  Some recommendations were good, and some not s...
# 11            All/most recommendations were very good
# 12                  All/most recommendations were bad
# 13  Some recommendations were good, and some not s...
# 14  Some recommendations were good, and some not s...
# 15                  All/most recommendations were bad
# 16  Some recommendations were good, and some not s...
# 17  Some recommendations were good, and some not s...
# 18  Some recommendations were good, and some not s...
# 19  Some recommendations were good, and some not s...
# 20  Some recommendations were good, and some not s...
# 21  Some recommendations were good, and some not s...
# 22  Some recommendations were good, and some not s...
# 23  Some recommendations were good, and some not s...
# 24            All/most recommendations were very good
# 25  Some recommendations were good, and some not s...
# 26  Some recommendations were good, and some not s...
# 27  Some recommendations were good, and some not s...
# 28                  All/most recommendations were bad
# 29  Some recommendations were good, and some not s...
# 30  Some recommendations were good, and some not s...
# 31  Some recommendations were good, and some not s...
# 32  Some recommendations were good, and some not s...
# 33  Some recommendations were good, and some not s...
# 34  Some recommendations were good, and some not s...
# 35  Some recommendations were good, and some not s...
# 36  Some recommendations were good, and some not s...
# 37  Some recommendations were good, and some not s...
# 38  Some recommendations were good, and some not s...
# 39                  All/most recommendations were bad
# 40  Some recommendations were good, and some not s...
# 41  Some recommendations were good, and some not s...
# 42  Some recommendations were good, and some not s...
# 43                  All/most recommendations were bad
# 44  Some recommendations were good, and some not s...
# 45  Some recommendations were good, and some not s...
# 46                  All/most recommendations were bad
# 47  Some recommendations were good, and some not s...
# 48  Some recommendations were good, and some not s...
# 49  Some recommendations were good, and some not s...
#
#                        batchID                      gameID  \
# 0   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG037XD21ETQMNRH61JB
# 1   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0NR42X0Z0W8FXYAX3C
# 2   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0SQ7KHVD5TX15VWEKM
# 3   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0C0GYCD4B6343VXN1J
# 4   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0B1WYNVB34CD3YG199
# 5   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0WS3070TEH7QAHBEBT
# 6   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0RCRR9S5ESQGNXAEB8
# 7   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG09TAZM5RN085BR0Y14
# 8   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0YNHSFF4VPEFEQ2TEE
# 9   01J1MVFFXJVAHG57XFST4Q2TJR  01J1MVFG0B1WYNVB34CTYBASN7
# 10  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR361V1Q7G5PN2KBMQECY
# 11  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35MY3302JP03GHEAQXZ
# 12  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR3677BNQZ3DAVHGY0PHC
# 13  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35DKE1C19JJJSRHBAY2
# 14  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35X0V4EDVH1QJRH8F37
# 15  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR360P82SQ2CHFG58EN69
# 16  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35YKDS07N7B78Q57KS4
# 17  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35SF8DVP2RNT5QY93V3
# 18  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR36BV13A3ZQX9F3B845D
# 19  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35VP0BXQFZ4PGBD8G4W
# 20  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35WTJ5RBCHREGD8CDHH
# 21  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35VP0BXQFZ4P411NHN9
# 22  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35PPS0595EZG4W42NYY
# 23  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR364AREH72ABKJMY7KAT
# 24  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35ZJXCE7S9V97F7RR4R
# 25  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35WTJ5RBCHREWNP9JQE
# 26  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR35E7VWG9WP0T22V53DS
# 27  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PYR36A532JD751652QTEYF
# 28  01J1PYR33SKJ9MYPR20ZAVKDE9  01J1PY
# 47  01J1R3TBS2CD61Y2RM8KH61CQ1  01J1R3TMB3VBGDN1DTTEQ12TMR
# 48  01J1R9MF8G40TGT9H1RJ4F81MT  01J1R9PEQZW5P9EHAVZQVVQJ76
# 49  01J1R4SDN425RPYBE2ZDNBVA8Z  01J1R4SM01ZQYFRW0CNKG2KB24

# %%
list(player_df[player_df['feedback'].notna()]['feedback'])
# Out:
# ['Very interesting study, hope all goes well!',
#  '6658badc8ce40f13d68d7d85',
#  'Illustrations were great and I enjoyed all the hobbies too.',
#  'An interesting experiment, and no problems encountered.',
#  'last 10 profiles were all the same two profiles',
#  'no problems',
#  'I encountered no issues and enjoyed partaking. ',
#  'Thank you for allowing me to take part ',
#  'very interesting study.',
#  'I encounterd none.']

# %% [markdown]
# ### What were the demographics of prolific participants?

# %%
continuous_columns = ['Time taken', 'Age']
player_df["Time taken"] = pd.to_numeric(player_df["Time taken"], errors='coerce')
player_df["Age"] = pd.to_numeric(player_df["Age"], errors='coerce')

categorical_columns = [
    'Gender', 'Sex', 'Ethnicity simplified', 'Country of birth', 
    'Country of residence', 'Nationality', 'Language', 'Student status', 
    'Employment status'
]
player_df['Time taken'] = player_df['Time taken'] / 60
continuous_summary = {}
categorical_summaries = {}
for column in continuous_columns:
    continuous_summary[column] = {
        'mean': player_df[column].mean(),
        'median': player_df[column].median(),
        'max': player_df[column].max(),
        'min': player_df[column].min(),
        'std_dev': player_df[column].std()
    }
for column in categorical_columns:
    categorical_summaries[column] = player_df[column].value_counts().to_dict()
continuous_summary_df = pd.DataFrame.from_dict(continuous_summary, orient='index').transpose()
categorical_summary_dfs = {col: pd.DataFrame.from_dict(categorical_summaries[col], orient='index', columns=['count']) for col in categorical_columns}

# %%
for column in categorical_columns:
    print(column)
    print(categorical_summaries[column])
# Out:
# Gender
# {'Woman (including Trans Female/Trans Woman)': 20, 'Man (including Trans Male/Trans Man)': 18, 'Non-binary (would like to give more detail)': 10, 'CONSENT_REVOKED': 1}
# Sex
# {'Female': 27, 'Male': 20, 'CONSENT_REVOKED': 1, 'Prefer not to say': 1}
# Ethnicity simplified
# {'White': 36, 'Mixed': 4, 'Black': 4, 'Asian': 3, 'Other': 1, 'CONSENT_REVOKED': 1}
# Country of birth
# {'United Kingdom': 36, 'Singapore': 2, 'United States': 2, 'Bulgaria': 1, 'Ireland': 1, 'Poland': 1, 'Hungary': 1, 'Zimbabwe': 1, 'CONSENT_REVOKED': 1, 'Pakistan': 1, 'Nigeria': 1, 'China': 1}
# Country of residence
# {'United Kingdom': 48, 'CONSENT_REVOKED': 1}
# Nationality
# {'United Kingdom': 41, 'United States': 2, 'Singapore': 1, 'Poland': 1, 'Hungary': 1, 'CONSENT_REVOKED': 1, 'Nigeria': 1, 'China': 1}
# Language
# {'English': 44, 'Bulgarian': 1, 'Polish': 1, 'Swahili': 1, 'CONSENT_REVOKED': 1, 'Chinese': 1}
# Student status
# {'No': 32, 'Yes': 11, 'DATA_EXPIRED': 5, 'CONSENT_REVOKED': 1}
# Employment status
# {'Full-Time': 22, 'Part-Time': 8, 'DATA_EXPIRED': 7, 'Unemployed (and job seeking)': 6, "Not in paid work (e.g. homemaker', 'retired or disabled)": 3, 'Due to start a new job within the next month': 2, 'CONSENT_REVOKED': 1}

# %%
display.Image("Demographic_Info.png")

# %% [markdown]
# ### What kinds of characters did they pick to play?

# %%
character_df['job_type'] = character_df['job_type'].replace({
    'No Higher Education Job': 'No Degree Job',
    'Higher Education Job': 'Degree Job'
})



merged_df = pd.merge(player_df, character_df, left_on='chosenProfile', right_on='profile_ID')

character_columns = ['age', 'main_hobby', 'job_type', 
                     'face_mood', 'hair_short', 'skin_dark', 
                     'has_facial_hair', 'has_accessories', 'pose', 'job']

rows = 5
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(5, 8), dpi=200)
axes = axes.flatten()

for i, column in enumerate(character_columns):
    total_value_counts = character_df[column].value_counts()
    picked_value_counts = merged_df[column].value_counts()
    normalized_counts = (picked_value_counts / total_value_counts).fillna(0) * 100  # Normalize to get percentages
    
    if column in ['hair_short', 'skin_dark', 'has_facial_hair', 'has_accessories']:
        normalized_counts.index = normalized_counts.index.map({False: 'False', True: 'True'})
    
    axes[i].bar(normalized_counts.index, normalized_counts.values)
    axes[i].set_title(f'{column}')
    axes[i].set_ylabel('')
    axes[i].tick_params(axis='x', rotation=90)

plt.subplots_adjust(hspace=1)
plt.show()

# %% [markdown]
# ### What attributes influenced them to pick the character? In which attributes do they consider themselves to be similar to their character?
#
# Survey Questions:
# - Check whether the character you chose is similar to you or not
# - How much did each characteristic influence your decision to choose this character?

# %%
influence_columns = [col for col in characterChoiceSurvey_df.columns if 'Influence' in col]
similarity_columns = [col for col in characterChoiceSurvey_df.columns if 'Similarity' in col]
influence_categories = ['notInfluential', 'somewhatInfluential', 'veryInfluential']
similarity_categories = ['notSimilar', 'somewhatSimilar', 'verySimilar']

influence_counts = {col: characterChoiceSurvey_df[col].value_counts(normalize=True).reindex(influence_categories, fill_value=0) for col in influence_columns}
similarity_counts = {col: characterChoiceSurvey_df[col].value_counts(normalize=True).reindex(similarity_categories, fill_value=0) for col in similarity_columns}
fig, axs = plt.subplots(len(influence_columns), 2, figsize=(6, 3), sharex='col', dpi=200)

colors = ['#fc8d59', '#f7f788', '#91cf60']

for row, (col, counts) in enumerate(influence_counts.items()):
    counts.plot(kind='bar', ax=axs[row, 0], color=colors, legend=False)
    axs[row, 0].set_ylabel(col.replace('_', ' ').replace('Influence ', ''), rotation=0, labelpad=50)
    axs[row, 0].set_xlabel('')
    if row == len(influence_columns) - 1:  
        axs[row, 0].set_xticklabels(['Not Influential', 'Somewhat Influential', 'Very Influential'], rotation=0)
    axs[row, 0].set_ylim(0, 0.8)

for row, (col, counts) in enumerate(similarity_counts.items()):
    counts.plot(kind='bar', ax=axs[row, 1], color=colors, legend=False)
    axs[row, 1].set_ylabel('')
    axs[row, 1].set_xlabel('')
    if row == len(similarity_columns) - 1: 
        axs[row, 1].set_xticklabels(['Not Similar', 'Somewhat Similar', 'Very Similar'], rotation=0)
    axs[row, 1].set_ylim(0, 0.8)

axs[0, 0].set_title('Influence')
axs[0, 1].set_title('Similarity')

plt.tight_layout()
plt.subplots_adjust(left=0.2, top=0.9)
plt.show()

# %% [markdown]
# ### Which types of characters did they like/dislike during swiping?

# %%
merged_df = pd.merge(SwipeDecision_df, character_df, left_on='likedProfile', right_on='profile_ID')
# merged_df['job_type'] = merged_df['job_type'].replace({
#     'No Higher Education Job': 'No Degree Job',
#     'Higher Education Job': 'Degree Job'
# })
character_columns = ['age', 'main_hobby', 'job_type', 
                     'face_mood', 'hair_short', 'skin_dark', 
                     'has_facial_hair', 'has_accessories', 'pose', 'job']

rows = 5
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(5, 8), dpi=200)
axes = axes.flatten()

for i, column in enumerate(character_columns):
    total_value_counts = character_df[column].value_counts()
    picked_value_counts = merged_df[column].value_counts()
    normalized_counts = (picked_value_counts / total_value_counts).fillna(0) * 100  # Normalize to get percentages
    
    if column in ['hair_short', 'skin_dark', 'has_facial_hair', 'has_accessories']:
        normalized_counts.index = normalized_counts.index.map({False: 'False', True: 'True'})
    
    axes[i].bar(normalized_counts.index, normalized_counts.values)
    axes[i].set_title(f'{column}')
    axes[i].set_ylabel('')
    axes[i].tick_params(axis='x', rotation=90)

plt.subplots_adjust(hspace=1)
plt.show()
# Out:
# /Users/franziskahafner/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1204: RuntimeWarning: invalid value encountered in cast
#   if not (lk == lk.astype(rk.dtype))[~np.isnan(lk)].all():

# %% [markdown]
# ### Which attributes did they say made them pick one character over another during swiping?
#
# Survey Question"
#  - For each of the following profile characteristics, indicate whether the chosen character was better, both were about the same, or the other character was better.

# %%
attribute_columns = ['AttributeAge', 'AttributeAppearance', 'AttributeHobbies', 'AttributeJob']
attribute_categories = ['notChosenBetter', 'same', 'chosenBetter']

filtered_df = SwipeProfileProfileChoiceSurvey_df[SwipeProfileProfileChoiceSurvey_df['attentionCheck'] != 'attentionAgeIsSame']

attribute_counts = {
    col: filtered_df[col].value_counts(normalize=True).reindex(attribute_categories, fill_value=0) 
    if col == 'AttributeAge' else 
    SwipeProfileProfileChoiceSurvey_df[col].value_counts(normalize=True).reindex(attribute_categories, fill_value=0)
    for col in attribute_columns
}

fig, axs = plt.subplots(len(attribute_columns), 1, figsize=(3, 3), sharex=True, dpi=200)

colors = ['#fc8d59', '#f7f788', '#91cf60']

for row, (col, counts) in enumerate(attribute_counts.items()):
    counts.plot(kind='bar', ax=axs[row], color=colors, legend=False)
    axs[row].set_ylabel(col.replace('Attribute', ''), rotation=0, labelpad=50)
    axs[row].set_xlabel('')
    if row == len(attribute_columns) - 1:
        axs[row].set_xticklabels(attribute_categories, rotation=0)
    axs[row].set_ylim(0, 1)

axs[0].set_title('')
plt.tight_layout()
plt.subplots_adjust(left=0.15, top=0.95)
plt.show()

# %% [markdown]
# ### How did the perceived difficulty of their choice change during the experiment?
#
# Survey Question:
#  - How well do the recommended characters fit with your character?

# %%
choice_column = 'AttributeDifficulty'
choice_categories = [
    'chosenBetter', 
    'bothGood',
    'neitherGood', 
    'random'
]

choice_counts = SwipeProfileProfileChoiceSurvey_df[choice_column].value_counts(normalize=True).reindex(choice_categories, fill_value=0)
wrapped_labels = ['\n'.join(textwrap.wrap(label, width=20)) for label in choice_categories]
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)
colors = ['#91cf60','#f7f788', '#fc8d59', 'grey']
choice_counts.plot(kind='barh', ax=ax, color=colors, legend=False)
ax.set_xlabel('')
ax.set_yticklabels(wrapped_labels, rotation=0)
ax.set_xlim(0, 0.5)
ax.set_title('')
plt.tight_layout()
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# ### How did they perceive the recommendations to improve during the experiment?
#
# Survey Question:
# - Do you feel that the recommendation system has learned and improved its suggestions since you began interacting with it?

# %%
rounds_played_categories = [10, 20, 30, 40, 50]
improvement_categories = ['worse', 'no', 'somewhat', 'better', 'notSure']

improvement_counts = {
    rounds: SwipeProfileRecSystemSurvey_df[SwipeProfileRecSystemSurvey_df['roundsPlayed'] == rounds]['Improvement'].value_counts(normalize=True).reindex(improvement_categories, fill_value=0)
    for rounds in rounds_played_categories
}

fig, axs = plt.subplots(len(rounds_played_categories), 1, figsize=(3, 3), sharex=True, dpi=200)

colors = ['#d73027', '#fc8d59', '#f7f788', '#91cf60', 'grey']

for row, (rounds, counts) in enumerate(improvement_counts.items()):
    counts.plot(kind='bar', ax=axs[row], color=colors, legend=False)
    axs[row].set_ylabel(f'Rounds {rounds}', rotation=0, labelpad=50)
    axs[row].set_xlabel('')
    if row == len(rounds_played_categories) - 1:
        axs[row].set_xticklabels(improvement_categories, rotation=0)
    axs[row].set_ylim(0, 1)

axs[0].set_title('')

plt.tight_layout()
plt.subplots_adjust(left=0.15, top=0.95)
plt.show()

# %% [markdown]
# ### How did they perceive the recommendation variety to change during the experiment?
#
# Survey Question:
# - How would you describe the variety of user profiles you get recommended?

# %%
rounds_played_categories = [10, 20, 30, 40, 50]
variety_categories = ['tooLittle', 'goodAmount', 'tooMuch', 'notSure']

variety_counts = {
    rounds: SwipeProfileRecSystemSurvey_df[SwipeProfileRecSystemSurvey_df['roundsPlayed'] == rounds]['Variety'].value_counts(normalize=True).reindex(variety_categories, fill_value=0)
    for rounds in rounds_played_categories
}

fig, axs = plt.subplots(len(rounds_played_categories), 1, figsize=(3, 3), sharex=True, dpi=200)

colors = ['#fc8d59', '#f7f788', '#91cf60', 'grey']

for row, (rounds, counts) in enumerate(variety_counts.items()):
    counts.plot(kind='bar', ax=axs[row], color=colors, legend=False)
    axs[row].set_ylabel(f'Rounds {rounds}', rotation=0, labelpad=50)
    axs[row].set_xlabel('')
    if row == len(rounds_played_categories) - 1:  # Only set x-tick labels on the bottom subplot
        axs[row].set_xticklabels(variety_categories, rotation=0)
    axs[row].set_ylim(0, 1)

axs[0].set_title('')

plt.tight_layout()
plt.subplots_adjust(left=0.15, top=0.95)
plt.show()

# %% [markdown]
# ### Which attributes do they think the algorithm learnt?
#
# Survey Question:
# - To what extent do you think the algorithm learned about your character’s preferences regarding the following attributes? Rank each:

# %%
attribute_columns = [col for col in endRecSystemSurvey_df.columns if 'algorithmLearntAttribute' in col]
attribute_categories = ['Did not learn', 'Learned slowly', 'Learned quickly']

attribute_counts = {col: endRecSystemSurvey_df[col].value_counts(normalize=True).reindex(attribute_categories, fill_value=0) for col in attribute_columns}

fig, axs = plt.subplots(len(attribute_columns), 1, figsize=(4, 3), sharex=True, dpi=200)
colors = ['#fc8d59', '#f7f788', '#91cf60']
for row, (col, counts) in enumerate(attribute_counts.items()):
    counts.plot(kind='bar', ax=axs[row], color=colors, legend=False)
    axs[row].set_ylabel(col.replace('algorithmLearntAttribute-', ''), rotation=0, labelpad=50)
    axs[row].set_xlabel('')
    axs[row].set_xticklabels(attribute_categories, rotation=0)
    axs[row].set_ylim(0, 0.7)

fig.suptitle('')

plt.tight_layout()
plt.subplots_adjust(left=0.2, top=0.9)
plt.show()

# %% [markdown]
# ### How did they perceive algorithm diversity?
#
# Survey Question:
# - Regarding the diversity of recommendations, do you think:

# %%
choice_column = 'recommendationDiversity'
choice_categories = [
    'The recommendations were too varied and inconsistent', 
    'The diversity of recommendations was balanced and appropriate', 
    'The recommendations were too similar and lacked diversity'
]
choice_counts = endRecSystemSurvey_df[choice_column].value_counts(normalize=True).reindex(choice_categories, fill_value=0)
wrapped_labels = ['\n'.join(textwrap.wrap(label, width=20)) for label in choice_categories]
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)
colors = ['#66c2a5', '#fc8d62', '#8da0cb']
choice_counts.plot(kind='barh', ax=ax, color=colors, legend=False)
ax.set_xlabel('')
ax.set_yticklabels(wrapped_labels, rotation=0)
ax.set_xlim(0, 0.5)
ax.set_title('')
plt.tight_layout()
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# ### How did they perceive algorithm quality?
#
# Survey Question:
# - Regarding the quality of recommendations, do you think:

# %%
choice_column = 'recommendationQuality'
choice_categories = ["All/most recommendations were very good", 
                     "Some recommendations were good, and some not so good", 
                     "All/most recommendations were bad"]
choice_counts = endRecSystemSurvey_df[choice_column].value_counts(normalize=True).reindex(choice_categories, fill_value=0)
wrapped_labels = ['\n'.join(textwrap.wrap(label, width=20)) for label in choice_categories]
fig, ax = plt.subplots(figsize=(4,3), dpi=200)
colors = ['#66c2a5', '#fc8d62', '#8da0cb']
choice_counts.plot(kind='barh', ax=ax, color=colors, legend=False)
ax.set_xlabel('')
ax.set_yticklabels(wrapped_labels, rotation=0)
ax.set_xlim(0, 0.85)
ax.set_title('')
plt.tight_layout()
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# ### Which type of algorithm do they think they got?
#
# Survey Question:
# - Which of the following algorithms do you think was used to recommend profiles to you during the previous experiment?

# %%
choice_column = 'algorithmChoice'
choice_categories = ["An algorithm that learned your preferences and recommended profiles similar to those you liked.",
                          "An algorithm that ranked profiles based on their popularity and suggested profiles with similar rankings to yours.",
                          "An algorithm that provided random profile recommendations."]
choice_counts = endRecSystemSurvey_df[choice_column].value_counts(normalize=True).reindex(choice_categories, fill_value=0)
wrapped_labels = ['\n'.join(textwrap.wrap(label, width=25)) for label in choice_categories]
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)
colors = ['#66c2a5', '#fc8d62', '#8da0cb']
choice_counts.plot(kind='barh', ax=ax, color=colors, legend=False)
ax.set_xlabel('')
ax.set_yticklabels(wrapped_labels, rotation=0)
ax.set_xlim(0, 0.6)
ax.set_title('')
plt.tight_layout()
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# ### What types of factors do they consider when dating? What factors do they think an algorithm should be allowed to consider?
#
# Survey Questions:
# - What factors would you consider when determining if someone is a good match on a dating app? Rank each:
# - Dating apps use various aspects of user profiles to make recommendations. From an ethical standpoint, which of the following factors do you believe should be permissible for them to consider? Rank each:

# %%
algorithm_columns = [col for col in endDatingAppSurvey_df.columns if 'AlgorithmShouldUse' in col]
influence_columns = [col for col in endDatingAppSurvey_df.columns if 'PersonalInfluence' in col]

algorithm_categories = ['Should definitely use', 'Should maybe use', 'Should maybe not use', 'Should definitely not use']
influence_categories = ['Very Important', 'Quite Important', 'Not Very Important', 'Not Important', 'Prefer not to answer']

algorithm_counts = {col: endDatingAppSurvey_df[col].value_counts(normalize=True).reindex(algorithm_categories, fill_value=0) for col in algorithm_columns}
influence_counts = {col: endDatingAppSurvey_df[col].value_counts(normalize=True).reindex(influence_categories, fill_value=0) for col in influence_columns}

colors_algorithm = ['#1a9850', '#91cf60', '#f7f788', '#fc8d59']
colors_influence = ['#1a9850', '#91cf60', '#f7f788', '#fc8d59', 'gray']

def split_labels(labels):
    split_points = {
        'Should definitely use': 'Should definitely\nuse',
        'Should maybe use': 'Should maybe\nuse',
        'Should maybe not use': 'Should maybe\nnot use',
        'Should definitely not use': 'Should definitely\nnot use',
        'Very Important': 'Very\nImportant',
        'Quite Important': 'Quite\nImportant',
        'Not Very Important': 'Not Very\nImportant',
        'Not Important': 'Not\nImportant',
        'Prefer not to answer': 'Prefer not to\nanswer'
    }
    return [split_points[label] for label in labels]
fig, axs = plt.subplots(len(algorithm_columns), 2, figsize=(7, 4), sharex='col', dpi=200)

for row, (col, counts) in enumerate(algorithm_counts.items()):
    counts.plot(kind='bar', ax=axs[row, 0], color=colors_algorithm, legend=False)
    axs[row, 0].set_ylabel(col.replace('AlgorithmShouldUse-', ''), rotation=0, labelpad=50)
    axs[row, 0].set_xlabel('')
    if row == len(algorithm_columns) - 1:
        axs[row, 0].set_xticklabels(split_labels(algorithm_categories), rotation=0)
    axs[row, 0].set_ylim(0, 1)

for row, (col, counts) in enumerate(influence_counts.items()):
    counts.plot(kind='bar', ax=axs[row, 1], color=colors_influence, legend=False)
    axs[row, 1].set_xlabel('')
    if row == len(influence_columns) - 1:
        axs[row, 1].set_xticklabels(split_labels(influence_categories), rotation=0)
    axs[row, 1].set_ylim(0, 1)

axs[0, 0].set_title('Algorithm Should Use')
axs[0, 1].set_title('Personal Influence')

plt.tight_layout()
plt.subplots_adjust(left=0.2, top=0.9)
plt.show()

# %% [markdown]
# ### What dating apps have they used before?
#
# Survey Question:
# - Which dating apps have you used before? (Check all that apply)

# %%
app_counts = {}
for apps in endDatingAppSurvey_df['datingAppsUsed']:
    app_list = ast.literal_eval(apps)
    for app in app_list:
        if app in app_counts:
            app_counts[app] += 1
        else:
            app_counts[app] = 1

app_counts_df = pd.DataFrame(list(app_counts.items()), columns=['App', 'Count'])

app_counts_df = app_counts_df.sort_values(by='Count', ascending=False)
plt.figure(figsize=(4, 3), dpi=200)
plt.barh(app_counts_df['App'], app_counts_df['Count'], color='grey')
plt.xlabel('')
plt.ylabel('')
plt.title('')
plt.tight_layout()
plt.show()
