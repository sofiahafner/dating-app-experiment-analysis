# %%
import pandas as pd

# %%
path = "/Users/franziskahafner/Desktop/oii/trinity/thesis/experiment_data/dating-app-experiment-2024-06-19-10-43-43/"

batch_df = pd.read_csv(path+"batch.csv")
game_df = pd.read_csv(path+"game.csv")
global_df = pd.read_csv(path+"global.csv")
player_df_org = pd.read_csv(path+"player.csv")
round_df = pd.read_csv(path+"round.csv")
stage_df = pd.read_csv(path+"stage.csv")
playerGame_df = pd.read_csv(path+"playerGame.csv")
playerRound_df = pd.read_csv(path+"playerRound.csv")
playerStage_df = pd.read_csv(path+"playerStage.csv")

# %%
dataframes = {
    "batch_df": batch_df,
    "game_df": game_df,
    "global_df": global_df,
    "player_df": player_df_org,
    "round_df": round_df,
    "stage_df": stage_df,
    "playerGame_df": playerGame_df,
    "playerRound_df": playerRound_df,
    "playerStage_df": playerStage_df
}

def print_column_names(dfs):
    for name, df in dfs.items():
        print(f"Column names in {name}:")
        for col in df.columns:
            print(f"  - {col}")
        print()

print_column_names(dataframes)
# Out:
# Column names in batch_df:
#   - id
#   - config
#   - configLastChangedAt
#   - endedReason
#   - endedReasonLastChangedAt
#   - initialized
#   - initializedLastChangedAt
#   - lobbyConfig
#   - lobbyConfigLastChangedAt
#   - status
#   - statusLastChangedAt
#
# Column names in game_df:
#   - id
#   - actualPlayerCount
#   - actualPlayerCountLastChangedAt
#   - batchID
#   - batchIDLastChangedAt
#   - ended
#   - endedLastChangedAt
#   - endedReason
#   - endedReasonLastChangedAt
#   - groupID
#   - groupIDLastChangedAt
#   - lobbyTimerID
#   - lobbyTimerIDLastChangedAt
#   - roundIndex
#   - roundIndexLastChangedAt
#   - stageID
#   - stageIDLastChangedAt
#   - start
#   - startLastChangedAt
#   - starting
#   - startingLastChangedAt
#   - status
#   - statusLastChangedAt
#   - treatment
#   - treatmentLastChangedAt
#   - treatmentName
#   - treatmentNameLastChangedAt
#
# Column names in global_df:
#   - id
#   - experimentOpen
#   - experimentOpenLastChangedAt
#
# Column names in player_df:
#   - id
#   - chosenProfile
#   - chosenProfileLastChangedAt
#   - dislikedProfiles
#   - dislikedProfilesLastChangedAt
#   - ended
#   - endedLastChangedAt
#   - exitStepDone
#   - exitStepDoneLastChangedAt
#   - exitSurvey
#   - exitSurveyLastChangedAt
#   - finalElo
#   - finalEloLastChangedAt
#   - gameID
#   - gameIDLastChangedAt
#   - introDone
#   - introDoneLastChangedAt
#   - likedProfiles
#   - likedProfilesLastChangedAt
#   - nextRecommendations
#   - nextRecommendationsLastChangedAt
#   - opponentIDs
#   - opponentIDsLastChangedAt
#   - participantID
#   - participantIDLastChangedAt
#   - participantIdentifier
#   - participantIdentifierLastChangedAt
#   - recAlgorithm
#   - recAlgorithmLastChangedAt
#   - roundsPlayed
#   - roundsPlayedLastChangedAt
#   - treatment
#   - treatmentLastChangedAt
#   - treatmentName
#   - treatmentNameLastChangedAt
#   - urlParams
#   - urlParamsLastChangedAt
#
# Column names in round_df:
#   - id
#   - batchID
#   - batchIDLastChangedAt
#   - ended
#   - endedLastChangedAt
#   - gameID
#   - gameIDLastChangedAt
#   - index
#   - indexLastChangedAt
#   - name
#   - nameLastChangedAt
#   - stageIndex
#   - stageIndexLastChangedAt
#   - start
#   - startLastChangedAt
#
# Column names in stage_df:
#   - id
#   - batchID
#   - batchIDLastChangedAt
#   - duration
#   - durationLastChangedAt
#   - ended
#   - endedLastChangedAt
#   - gameID
#   - gameIDLastChangedAt
#   - index
#   - indexLastChangedAt
#   - initialized
#   - initializedLastChangedAt
#   - name
#   - nameLastChangedAt
#   - roundID
#   - roundIDLastChangedAt
#   - start
#   - startLastChangedAt
#   - started
#   - startedLastChangedAt
#   - timerID
#   - timerIDLastChangedAt
#
# Column names in playerGame_df:
#   - id
#   - batchID
#   - batchIDLastChangedAt
#   - gameID
#   - gameIDLastChangedAt
#   - playerID
#   - playerIDLastChangedAt
#
# Column names in playerRound_df:
#   - id
#   - batchID
#   - batchIDLastChangedAt
#   - gameID
#   - gameIDLastChangedAt
#   - playerID
#   - playerIDLastChangedAt
#   - roundID
#   - roundIDLastChangedAt
#
# Column names in playerStage_df:
#   - id
#   - CharacterChoice_Influence_Age
#   - CharacterChoice_Influence_AgeLastChangedAt
#   - CharacterChoice_Influence_Appearance
#   - CharacterChoice_Influence_AppearanceLastChangedAt
#   - CharacterChoice_Influence_Hobbies
#   - CharacterChoice_Influence_HobbiesLastChangedAt
#   - CharacterChoice_Influence_Job
#   - CharacterChoice_Influence_JobLastChangedAt
#   - CharacterChoice_Similarity_Similar_age
#   - CharacterChoice_Similarity_Similar_ageLastChangedAt
#   - CharacterChoice_Similarity_Similar_appearance
#   - CharacterChoice_Similarity_Similar_appearanceLastChangedAt
#   - CharacterChoice_Similarity_Similar_hobbies
#   - CharacterChoice_Similarity_Similar_hobbiesLastChangedAt
#   - CharacterChoice_Similarity_Similar_job
#   - CharacterChoice_Similarity_Similar_jobLastChangedAt
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Age
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-AgeLastChangedAt
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Appearance
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-AppearanceLastChangedAt
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Education Level
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Education LevelLastChangedAt
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Ethnicity
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-EthnicityLastChangedAt
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Hobbies
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-HobbiesLastChangedAt
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Physical Health
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Physical HealthLastChangedAt
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-Profession
#   - EndDatingAppSurvey_AlgorithmShouldUseRecommend-ProfessionLastChangedAt
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Age
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-AgeLastChangedAt
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Appearance
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-AppearanceLastChangedAt
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Education Level
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Education LevelLastChangedAt
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Ethnicity
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-EthnicityLastChangedAt
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Hobbies
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-HobbiesLastChangedAt
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Physical Health
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Physical HealthLastChangedAt
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Profession
#   - EndDatingAppSurvey_PersonalInfluenceFactorsFactor-ProfessionLastChangedAt
#   - EndDatingAppSurvey_activeOnDatingApps
#   - EndDatingAppSurvey_activeOnDatingAppsLastChangedAt
#   - EndDatingAppSurvey_datingAppsUsed
#   - EndDatingAppSurvey_datingAppsUsedLastChangedAt
#   - EndDatingAppSurvey_frequencyDatingAppUsage
#   - EndDatingAppSurvey_frequencyDatingAppUsageLastChangedAt
#   - EndRecSystemSurvey_additionalComments
#   - EndRecSystemSurvey_additionalCommentsLastChangedAt
#   - EndRecSystemSurvey_algorithmLearntAttribute-Age
#   - EndRecSystemSurvey_algorithmLearntAttribute-AgeLastChangedAt
#   - EndRecSystemSurvey_algorithmLearntAttribute-Appearance
#   - EndRecSystemSurvey_algorithmLearntAttribute-AppearanceLastChangedAt
#   - EndRecSystemSurvey_algorithmLearntAttribute-Hobbies
#   - EndRecSystemSurvey_algorithmLearntAttribute-HobbiesLastChangedAt
#   - EndRecSystemSurvey_algorithmLearntAttribute-Job
#   - EndRecSystemSurvey_algorithmLearntAttribute-JobLastChangedAt
#   - EndRecSystemSurvey_recommendationDiversity
#   - EndRecSystemSurvey_recommendationDiversityLastChangedAt
#   - EndRecSystemSurvey_recommendationQuality
#   - EndRecSystemSurvey_recommendationQualityLastChangedAt
#   - EndRecSystemSurvey_systemVariety
#   - EndRecSystemSurvey_systemVarietyLastChangedAt
#   - SwipeProfileChoiceSurvey_AttributeAge
#   - SwipeProfileChoiceSurvey_AttributeAgeLastChangedAt
#   - SwipeProfileChoiceSurvey_AttributeAppearance
#   - SwipeProfileChoiceSurvey_AttributeAppearanceLastChangedAt
#   - SwipeProfileChoiceSurvey_AttributeDifficulty
#   - SwipeProfileChoiceSurvey_AttributeDifficultyLastChangedAt
#   - SwipeProfileChoiceSurvey_AttributeHobbies
#   - SwipeProfileChoiceSurvey_AttributeHobbiesLastChangedAt
#   - SwipeProfileChoiceSurvey_AttributeJob
#   - SwipeProfileChoiceSurvey_AttributeJobLastChangedAt
#   - SwipeProfileRecommendationSurvey_Improvement
#   - SwipeProfileRecommendationSurvey_ImprovementLastChangedAt
#   - SwipeProfileRecommendationSurvey_Variety
#   - SwipeProfileRecommendationSurvey_VarietyLastChangedAt
#   - batchID
#   - batchIDLastChangedAt
#   - chosenCharacterBeard
#   - chosenCharacterBeardLastChangedAt
#   - chosenCharacterGlasses
#   - chosenCharacterGlassesLastChangedAt
#   - chosenCharacterHair
#   - chosenCharacterHairLastChangedAt
#   - chosenCharacterHobby
#   - chosenCharacterHobbyLastChangedAt
#   - chosenProfile
#   - chosenProfileLastChangedAt
#   - dislikedProfile
#   - dislikedProfileLastChangedAt
#   - gameID
#   - gameIDLastChangedAt
#   - likedProfile
#   - likedProfileLastChangedAt
#   - playerID
#   - playerIDLastChangedAt
#   - roundID
#   - roundIDLastChangedAt
#   - stageID
#   - stageIDLastChangedAt
#   - submit
#   - submitLastChangedAt

# %%
playerStage_df
# Out:
#                              id CharacterChoice_Influence_Age  \
# 0    01J0QXS1V5NXCKNABCYBGR8JTY                           NaN
# 1    01J0QXY3NA3AHGWRZXT2Z31YBK                           NaN
# 2    01J0QXZ529RVZN419XKNAREGZC                           NaN
# 3    01J0QY07YXHJK4F7CJ5ZP8VCJQ                           NaN
# 4    01J0QY0RB78TJT2YR26J852PKA                           NaN
# ..                          ...                           ...
# 105  01J0QXR13VJSHGRY0MGE4KDPV1                           NaN
# 106  01J0QXZ3NKJJKWHGNZ12F0S4W9                           NaN
# 107  01J0QY06ED4SV54F3783MJK51R                           NaN
# 108  01J0QXTX5VK80EJXE0C9CR1PGK                           NaN
# 109  01J0QXVAQ4DJ24FPWDFAZAVEE5                           NaN
#
#     CharacterChoice_Influence_AgeLastChangedAt  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 105                                        NaN
# 106                                        NaN
# 107                                        NaN
# 108                                        NaN
# 109                                        NaN
#
#     CharacterChoice_Influence_Appearance  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 105                                  NaN
# 106                                  NaN
# 107                                  NaN
# 108                                  NaN
# 109                                  NaN
#
#     CharacterChoice_Influence_AppearanceLastChangedAt  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 105                                               NaN
# 106                                               NaN
# 107                                               NaN
# 108                                               NaN
# 109                                               NaN
#
#     CharacterChoice_Influence_Hobbies  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 105                               NaN
# 106                               NaN
# 107                               NaN
# 108                               NaN
# 109                               NaN
#
#     CharacterChoice_Influence_HobbiesLastChangedAt  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 105                                            NaN
# 106                                            NaN
# 107                                            NaN
# 108                                            NaN
# 109                                            NaN
#
#     CharacterChoice_Influence_Job CharacterChoice_Influence_JobLastChangedAt  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
# 4                             NaN                                        NaN
# ..                            ...                                        ...
# 105                           NaN                                        NaN
# 106                           NaN                                        NaN
# 107                           NaN                                        NaN
# 108                           NaN                                        NaN
# 109                           NaN                                        NaN
#
#     CharacterChoice_Similarity_Similar_age  ... likedProfile  \
# 0                                      NaN  ...        174.0
# 1                                      NaN  ...         37.0
# 2                                      NaN  ...        196.0
# 3                                      NaN  ...        175.0
# 4                                      NaN  ...        106.0
# ..                                     ...  ...          ...
# 105                                    NaN  ...        151.0
# 106                                    NaN  ...        148.0
# 107                                    NaN  ...        219.0
# 108                                    NaN  ...        165.0
# 109                                    NaN  ...        218.0
#
#             likedProfileLastChangedAt                    playerID  \
# 0    2024-06-19T10:38:21.896834+01:00  01J0QXPJSBQXBYVH6TD639VDAH
# 1    2024-06-19T10:41:07.493595+01:00  01J0QXX40PG85F0EQD7VYYY5W6
# 2    2024-06-19T10:41:41.170295+01:00  01J0QXX40PG85F0EQD7VYYY5W6
# 3    2024-06-19T10:42:17.314308+01:00  01J0QXX40PG85F0EQD7VYYY5W6
# 4    2024-06-19T10:42:34.988124+01:00  01J0QXX40PG85F0EQD7VYYY5W6
# ..                                ...                         ...
# 105  2024-06-19T10:37:48.198883+01:00  01J0QXPJSBQXBYVH6TD639VDAH
# 106  2024-06-19T10:41:40.027081+01:00  01J0QXX40PG85F0EQD7VYYY5W6
# 107  2024-06-19T10:42:15.757855+01:00  01J0QXX40PG85F0EQD7VYYY5W6
# 108  2024-06-19T10:39:22.670817+01:00  01J0QXPJSBQXBYVH6TD639VDAH
# 109  2024-06-19T10:39:36.357514+01:00  01J0QXPJSBQXBYVH6TD639VDAH
#
#                 playerIDLastChangedAt                     roundID  \
# 0    2024-06-19T10:38:20.133227+01:00  01J0QXPN8XHFBEYZKYV53FKTKM
# 1    2024-06-19T10:41:05.834166+01:00  01J0QXX64CGBJ3ZBWVNED4QHEJ
# 2    2024-06-19T10:41:40.041106+01:00  01J0QXX64CGBJ3ZBWVNED4QHEJ
# 3    2024-06-19T10:42:15.773596+01:00  01J0QXX64CGBJ3ZBWVNED4QHEJ
# 4    2024-06-19T10:42:32.551306+01:00  01J0QXX64CGBJ3ZBWVNED4QHEJ
# ..                                ...                         ...
# 105  2024-06-19T10:37:46.619191+01:00  01J0QXPN8XHFBEYZKYV53FKTKM
# 106  2024-06-19T10:41:38.611202+01:00  01J0QXX64CGBJ3ZBWVNED4QHEJ
# 107    2024-06-19T10:42:14.2218+01:00  01J0QXX64CGBJ3ZBWVNED4QHEJ
# 108  2024-06-19T10:39:20.891462+01:00  01J0QXPN8XHFBEYZKYV53FKTKM
# 109  2024-06-19T10:39:34.756769+01:00  01J0QXPN8XHFBEYZKYV53FKTKM
#
#                  roundIDLastChangedAt                     stageID  \
# 0    2024-06-19T10:38:20.133227+01:00  01J0QXPNCJJ5W4TW9GDQ6CZZ8B
# 1    2024-06-19T10:41:05.834166+01:00  01J0QXX67457278V402E9DNPH1
# 2    2024-06-19T10:41:40.041106+01:00  01J0QXX6765FSEAM9XNSPFXQGX
# 3    2024-06-19T10:42:15.773596+01:00  01J0QXX679BCTA0K3EHHJKXM4E
# 4    2024-06-19T10:42:32.551306+01:00  01J0QXX67AQ03EV9W90XG415E1
# ..                                ...                         ...
# 105  2024-06-19T10:37:46.619191+01:00  01J0QXPNCGX451192V7APJV71J
# 106  2024-06-19T10:41:38.611202+01:00  01J0QXX6765FSEAM9XN59W09DB
# 107    2024-06-19T10:42:14.2218+01:00  01J0QXX679BCTA0K3EGRG275PR
# 108  2024-06-19T10:39:20.891462+01:00  01J0QXPNCPSN6APZVWK0646T86
# 109  2024-06-19T10:39:34.756769+01:00  01J0QXPNCPSN6APZVWNZ9VR75S
#
#                  stageIDLastChangedAt submit               submitLastChangedAt
# 0    2024-06-19T10:38:20.133227+01:00   True  2024-06-19T10:38:36.419003+01:00
# 1    2024-06-19T10:41:05.834166+01:00   True  2024-06-19T10:41:07.494058+01:00
# 2    2024-06-19T10:41:40.041106+01:00   True  2024-06-19T10:41:44.581061+01:00
# 3    2024-06-19T10:42:15.773596+01:00   True  2024-06-19T10:42:17.315109+01:00
# 4    2024-06-19T10:42:32.551306+01:00   True  2024-06-19T10:42:38.319773+01:00
# ..                                ...    ...                               ...
# 105  2024-06-19T10:37:46.619191+01:00   True  2024-06-19T10:37:48.199392+01:00
# 106  2024-06-19T10:41:38.611202+01:00   True  2024-06-19T10:41:40.027911+01:00
# 107    2024-06-19T10:42:14.2218+01:00   True  2024-06-19T10:42:15.758125+01:00
# 108  2024-06-19T10:39:20.891462+01:00   True  2024-06-19T10:39:29.309656+01:00
# 109  2024-06-19T10:39:34.756769+01:00   True     2024-06-19T10:39:36.358+01:00
#
# [110 rows x 107 columns]

# %% [markdown]
# ## Likes in Past Rounds to inform Recommendations:
#
# The json from this is then included in the treatment group experiments, to provide information on which other profiles have liked the current profile:

# %%
import json
from json import loads, dumps
import ast 

def str_to_list(list_str):
    try:
        return ast.literal_eval(list_str)
    except ValueError:
        return [] 

player_df_org['likedProfiles'] = player_df_org['likedProfiles'].apply(str_to_list)
player_df_org['dislikedProfiles'] = player_df_org['dislikedProfiles'].apply(str_to_list)

records = []
for index, row in player_df_org.iterrows():
    for liked, disliked in zip(row['likedProfiles'], row['dislikedProfiles']):
        record = {
            "participantID": row['id'],
            "chosenProfileID": row['chosenProfile'],
            "recommendedProfiles": [liked, disliked],
            "likedProfile": liked,
            "dislikedProfile": disliked
        }
        records.append(record)

expanded_df = pd.DataFrame(records)
json_output = expanded_df.to_json(orient='records')
parsed_json = json.loads(json_output)

with open('/Users/franziskahafner/Desktop/oii/trinity/thesis/experiment/dating-app-experiment/server/data/likesPastRounds.json', 'w') as f:
    json.dump(parsed_json, f, indent=2)

# %% [markdown]
# ### Player DF
# DF with information that is available on participant-level.
# Includes data on:
# - Participant ID
# - Which character they chose
# - Whether the game was ended or terminated
# - The participant identifyer (for Prolific)
# - Their treatment group

# %%
player_df = player_df_org[['id', 'chosenProfile', 'ended', 'participantID', 'participantIdentifier', 'treatmentName']]
player_df.head(3)
# Out:
#                            id  chosenProfile       ended  \
# 0  01J0QXPJSBQXBYVH6TD639VDAH             36  game ended
# 1  01J0QXX40PG85F0EQD7VYYY5W6             35  game ended
#
#                 participantID participantIdentifier treatmentName
# 0  01J0QXPJRYDJBSSEZTA142ZHX0          testdatastr1       Control
# 1  01J0QXX40AYY1JX0JH0E4DMWC1   testdatastructure 2       Control

# %% [markdown]
# ### Character Choice Survey:
#
# Df with information on why a participant chose the character they chose. Includes data on:
# - participant (/player) Id
# - how similar participant is to character in age, appearance, hobbies, and job
# - how nuch the character age, appearance, hobbies, and job influenced the choice of the character

# %%
characterChoiceSurvey_df = playerStage_df[['id',
'CharacterChoice_Influence_Age',
'CharacterChoice_Influence_Appearance',
'CharacterChoice_Influence_Hobbies',
'CharacterChoice_Influence_Job',
'CharacterChoice_Similarity_Similar_age',
'CharacterChoice_Similarity_Similar_appearance',
'CharacterChoice_Similarity_Similar_hobbies',
'CharacterChoice_Similarity_Similar_job',
'batchID',
'gameID',
'playerID',
'roundID']]
characterChoiceSurvey_df.columns = [col.replace('CharacterChoice_', '') for col in characterChoiceSurvey_df.columns]
columns_to_check = [col for col in characterChoiceSurvey_df.columns if 'id' not in col.lower()]
characterChoiceSurvey_df = characterChoiceSurvey_df.dropna(subset=columns_to_check, how='all')
characterChoiceSurvey_df.head(3)
# Out:
#                             id        Influence_Age Influence_Appearance  \
# 44  01J0QXXDYSG74MMKVHKB2A92AE       notInfluential  somewhatInfluential
# 80  01J0QXPXDA4PNQ1WJC8PP19W07  somewhatInfluential  somewhatInfluential
#
#    Influence_Hobbies        Influence_Job Similarity_Similar_age  \
# 44    notInfluential  somewhatInfluential            verySimilar
# 80   veryInfluential  somewhatInfluential        somewhatSimilar
#
#    Similarity_Similar_appearance Similarity_Similar_hobbies  \
# 44               somewhatSimilar                verySimilar
# 80                    notSimilar            somewhatSimilar
#
#    Similarity_Similar_job                     batchID  \
# 44        somewhatSimilar  01J0QXP6F8GS18SVA8ZGZTQVX3
# 80            verySimilar  01J0QXP6F8GS18SVA8ZGZTQVX3
#
#                         gameID                    playerID  \
# 44  01J0QXP6FR2RN1NFZB13VVKB0T  01J0QXX40PG85F0EQD7VYYY5W6
# 80  01J0QXP6FTM05EG6RC59T0XE7Q  01J0QXPJSBQXBYVH6TD639VDAH
#
#                        roundID
# 44  01J0QXX64CGBJ3ZBWVMY5EFFMP
# 80  01J0QXPN8XHFBEYZKYTQJXWV5Q

# %% [markdown]
# ### Dating App Usage Survey:
#
# Df with information on participant's experience with dating apps. Includes data on:
# - participant (/player) Id
# - whether, how much, and which dating apps they have used
# - which influences they take into consideration when on dating apps
# - which influences they think algorithms should take into consideration when using dating apps

# %%
endDatingAppSurvey_df = playerStage_df[['id',
    'EndDatingAppSurvey_AlgorithmShouldUseRecommend-Age',
    'EndDatingAppSurvey_AlgorithmShouldUseRecommend-Appearance',
    'EndDatingAppSurvey_AlgorithmShouldUseRecommend-Education Level',
    'EndDatingAppSurvey_AlgorithmShouldUseRecommend-Ethnicity',
    'EndDatingAppSurvey_AlgorithmShouldUseRecommend-Hobbies',
    'EndDatingAppSurvey_AlgorithmShouldUseRecommend-Physical Health',
    'EndDatingAppSurvey_AlgorithmShouldUseRecommend-Profession',
    'EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Age',
    'EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Appearance',
    'EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Education Level',
    'EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Ethnicity',
    'EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Hobbies',
    'EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Physical Health',
    'EndDatingAppSurvey_PersonalInfluenceFactorsFactor-Profession',
    'EndDatingAppSurvey_activeOnDatingApps',
    'EndDatingAppSurvey_datingAppsUsed',
    'EndDatingAppSurvey_frequencyDatingAppUsage',
    'batchID',
    'gameID',
    'playerID',
    'roundID'
]]
endDatingAppSurvey_df.columns = [col.replace('EndDatingAppSurvey_', '') for col in endDatingAppSurvey_df.columns]
columns_to_check = [col for col in endDatingAppSurvey_df.columns if 'id' not in col.lower()]
endDatingAppSurvey_df = endDatingAppSurvey_df.dropna(subset=columns_to_check, how='all')
endDatingAppSurvey_df.head(3)
# Out:
#                             id AlgorithmShouldUseRecommend-Age  \
# 34  01J0QXVVD7Z8H5WS60QE96ZF01                Should maybe use
# 56  01J0QY22JTEMEMG3EZAPRF41Z4                Should maybe use
#
#    AlgorithmShouldUseRecommend-Appearance  \
# 34                   Should maybe not use
# 56                       Should maybe use
#
#    AlgorithmShouldUseRecommend-Education Level  \
# 34                            Should maybe use
# 56                            Should maybe use
#
#    AlgorithmShouldUseRecommend-Ethnicity AlgorithmShouldUseRecommend-Hobbies  \
# 34                  Should maybe not use                    Should maybe use
# 56                      Should maybe use                Should maybe not use
#
#    AlgorithmShouldUseRecommend-Physical Health  \
# 34                            Should maybe use
# 56                       Should definitely use
#
#    AlgorithmShouldUseRecommend-Profession PersonalInfluenceFactorsFactor-Age  \
# 34                  Should definitely use                    Quite Important
# 56                       Should maybe use                                NaN
#
#    PersonalInfluenceFactorsFactor-Appearance  ...  \
# 34                            Very Important  ...
# 56                                       NaN  ...
#
#    PersonalInfluenceFactorsFactor-Hobbies  \
# 34                        Quite Important
# 56                                    NaN
#
#    PersonalInfluenceFactorsFactor-Physical Health  \
# 34                                  Not Important
# 56                                            NaN
#
#    PersonalInfluenceFactorsFactor-Profession  \
# 34                        Not Very Important
# 56                                       NaN
#
#                                    activeOnDatingApps datingAppsUsed  \
# 34  I am not currently active on dating apps but w...      ["Hinge"]
# 56           I have never been active on a dating app             []
#
#    frequencyDatingAppUsage                     batchID  \
# 34      A few times a week  01J0QXP6F8GS18SVA8ZGZTQVX3
# 56                     NaN  01J0QXP6F8GS18SVA8ZGZTQVX3
#
#                         gameID                    playerID  \
# 34  01J0QXP6FTM05EG6RC59T0XE7Q  01J0QXPJSBQXBYVH6TD639VDAH
# 56  01J0QXP6FR2RN1NFZB13VVKB0T  01J0QXX40PG85F0EQD7VYYY5W6
#
#                        roundID
# 34  01J0QXPN8YQGC8FVFYD3VCN929
# 56  01J0QXX64EJ1Z49RBQDE7X6J30
#
# [2 rows x 22 columns]

# %% [markdown]
# ### End Recommendation System Survey:
#
# Df with information on participant's experience with the experiment rec system after finishing experiment. Includes data on:
# - participant (/player) Id
# - to what extent they believe rec system has learnt profile attributes
# - how diverse they found the recommendations
# - how they perceived the quality of recommendations
# - how they perceived the variety of recommendations

# %%
endRecSystemSurvey_df = playerStage_df[['id',
    'EndRecSystemSurvey_additionalComments',
    'EndRecSystemSurvey_algorithmLearntAttribute-Age',
    'EndRecSystemSurvey_algorithmLearntAttribute-Appearance',
    'EndRecSystemSurvey_algorithmLearntAttribute-Hobbies',
    'EndRecSystemSurvey_algorithmLearntAttribute-Job',
    'EndRecSystemSurvey_recommendationDiversity',
    'EndRecSystemSurvey_recommendationQuality',
    'EndRecSystemSurvey_systemVariety',
    'batchID',
    'gameID',
    'playerID',
    'roundID'
]]
endRecSystemSurvey_df.columns = [col.replace('EndRecSystemSurvey_', '') for col in endRecSystemSurvey_df.columns]
columns_to_check = [col for col in endRecSystemSurvey_df.columns if 'id' not in col.lower()]
endRecSystemSurvey_df = endRecSystemSurvey_df.dropna(subset=columns_to_check, how='all')
endRecSystemSurvey_df.head(3)
# Out:
#                             id  additionalComments  \
# 33  01J0QXVHFB6R6HJZQK43M34RC3                 NaN
# 38  01J0QY1RD5WK6RMS7DCBVV53G9                 NaN
#
#    algorithmLearntAttribute-Age algorithmLearntAttribute-Appearance  \
# 33              Learned quickly                      Learned slowly
# 38              Learned quickly                     Learned quickly
#
#    algorithmLearntAttribute-Hobbies algorithmLearntAttribute-Job  \
# 33                  Learned quickly               Learned slowly
# 38                   Learned slowly               Learned slowly
#
#                               recommendationDiversity  \
# 33  The diversity of recommendations was balanced ...
# 38  The diversity of recommendations was balanced ...
#
#                                 recommendationQuality  \
# 33  Some recommendations were good, and some not s...
# 38            All/most recommendations were very good
#
#                                         systemVariety  \
# 33  Showed a variety of potential matches, even if...
# 38  Focused on suggesting matches closely aligned ...
#
#                        batchID                      gameID  \
# 33  01J0QXP6F8GS18SVA8ZGZTQVX3  01J0QXP6FTM05EG6RC59T0XE7Q
# 38  01J0QXP6F8GS18SVA8ZGZTQVX3  01J0QXP6FR2RN1NFZB13VVKB0T
#
#                       playerID                     roundID
# 33  01J0QXPJSBQXBYVH6TD639VDAH  01J0QXPN8YQGC8FVFYD3VCN929
# 38  01J0QXX40PG85F0EQD7VYYY5W6  01J0QXX64EJ1Z49RBQDE7X6J30

# %% [markdown]
# ### Recommendation System Survey during Swiping:
#
# Df with information on participant's perception of the recommendation system in 10 rec intervalls. Includes data on:
# - participant (/player) Id
# - if they think recs have improved in quality
# - if they think recs have improved in variety

# %%
# Original DataFrame
SwipeProfileRecSystemSurvey_df = playerStage_df[['id',
                                                'SwipeProfileRecommendationSurvey_Improvement',
                                                'SwipeProfileRecommendationSurvey_Variety',
                                                'batchID',
                                                'gameID',
                                                'playerID',
                                                'roundID']]

# Remove "SwipeProfileRecommendationSurvey_" from column names
SwipeProfileRecSystemSurvey_df.columns = [col.replace('SwipeProfileRecommendationSurvey_', '') for col in SwipeProfileRecSystemSurvey_df.columns]

# Dropping rows with all NaN values in the specified columns
columns_to_check = [col for col in SwipeProfileRecSystemSurvey_df.columns if 'id' not in col.lower()]
SwipeProfileRecSystemSurvey_df = SwipeProfileRecSystemSurvey_df.dropna(subset=columns_to_check, how='all')

# Display the first 3 rows of the updated DataFrame
SwipeProfileRecSystemSurvey_df.head(3)
# Out:
#                             id SwipeProfileRecommendationSurvey_Improvement  \
# 2   01J0QXZ529RVZN419XKNAREGZC                                        worse
# 4   01J0QY0RB78TJT2YR26J852PKA                                        worse
# 16  01J0QXQW7RBWHZPGVZ61YPFCBR                                        worse
#
#    SwipeProfileRecommendationSurvey_Variety                     batchID  \
# 2                                   tooMuch  01J0QXP6F8GS18SVA8ZGZTQVX3
# 4                                goodAmount  01J0QXP6F8GS18SVA8ZGZTQVX3
# 16                                  tooMuch  01J0QXP6F8GS18SVA8ZGZTQVX3
#
#                         gameID                    playerID  \
# 2   01J0QXP6FR2RN1NFZB13VVKB0T  01J0QXX40PG85F0EQD7VYYY5W6
# 4   01J0QXP6FR2RN1NFZB13VVKB0T  01J0QXX40PG85F0EQD7VYYY5W6
# 16  01J0QXP6FTM05EG6RC59T0XE7Q  01J0QXPJSBQXBYVH6TD639VDAH
#
#                        roundID
# 2   01J0QXX64CGBJ3ZBWVNED4QHEJ
# 4   01J0QXX64CGBJ3ZBWVNED4QHEJ
# 16  01J0QXPN8XHFBEYZKYV53FKTKM

# %% [markdown]
# ### Swipe Choice Survey during Swiping:
#
# Df with information on why participants chose a specific survey over another. Includes data on:
# - participant (/player) Id
# - for age, appearance, hobbies, and job, which of the two recommendations they prefered

# %%
SwipeProfileProfileChoiceSurvey_df = playerStage_df[['id',
'SwipeProfileChoiceSurvey_AttributeAge',
'SwipeProfileChoiceSurvey_AttributeAppearance',
'SwipeProfileChoiceSurvey_AttributeDifficulty',
'SwipeProfileChoiceSurvey_AttributeHobbies',
'SwipeProfileChoiceSurvey_AttributeJob',
'batchID',
'gameID',
'playerID',
'roundID']]
columns_to_check = [col for col in SwipeProfileProfileChoiceSurvey_df.columns if 'id' not in col.lower()]
SwipeProfileProfileChoiceSurvey_df = SwipeProfileProfileChoiceSurvey_df.dropna(subset=columns_to_check, how='all')

SwipeProfileProfileChoiceSurvey_df.head(3)
# Out:
#                             id SwipeProfileChoiceSurvey_AttributeAge  \
# 0   01J0QXS1V5NXCKNABCYBGR8JTY                                  same
# 11  01J0QXZG86BA3GSH93HS9F55PR                          chosenBetter
# 15  01J0QXQE3T69W2RCV7KAMFZQAK                                  same
#
#    SwipeProfileChoiceSurvey_AttributeAppearance  \
# 0                                  chosenBetter
# 11                                         same
# 15                                         same
#
#    SwipeProfileChoiceSurvey_AttributeDifficulty  \
# 0                                   hardNeither
# 11                                  hardNeither
# 15                                     hardBoth
#
#    SwipeProfileChoiceSurvey_AttributeHobbies  \
# 0                                       same
# 11                              chosenBetter
# 15                           notChosenBetter
#
#    SwipeProfileChoiceSurvey_AttributeJob                     batchID  \
# 0                           chosenBetter  01J0QXP6F8GS18SVA8ZGZTQVX3
# 11                                  same  01J0QXP6F8GS18SVA8ZGZTQVX3
# 15                                  same  01J0QXP6F8GS18SVA8ZGZTQVX3
#
#                         gameID                    playerID  \
# 0   01J0QXP6FTM05EG6RC59T0XE7Q  01J0QXPJSBQXBYVH6TD639VDAH
# 11  01J0QXP6FR2RN1NFZB13VVKB0T  01J0QXX40PG85F0EQD7VYYY5W6
# 15  01J0QXP6FTM05EG6RC59T0XE7Q  01J0QXPJSBQXBYVH6TD639VDAH
#
#                        roundID
# 0   01J0QXPN8XHFBEYZKYV53FKTKM
# 11  01J0QXX64CGBJ3ZBWVNED4QHEJ
# 15  01J0QXPN8XHFBEYZKYV53FKTKM

# %% [markdown]
# ## Swipe Decisions
#
# Df containing all swiping decisions. Includes information on:
# - Liked and disliked profile
# - participant (/player) Id

# %%
list(playerStage_df.columns)
SwipeDecision_df = playerStage_df[['id',
'dislikedProfile',
'likedProfile',
'batchID',
'gameID',
'playerID',
'roundID']]
columns_to_check = [col for col in SwipeDecision_df.columns if 'id' not in col.lower()]
SwipeDecision_df = SwipeDecision_df.dropna(subset=columns_to_check, how='all')

SwipeDecision_df.head(3)
# Out:
#                            id  dislikedProfile  likedProfile  \
# 0  01J0QXS1V5NXCKNABCYBGR8JTY            149.0         174.0
# 1  01J0QXY3NA3AHGWRZXT2Z31YBK            107.0          37.0
# 2  01J0QXZ529RVZN419XKNAREGZC             64.0         196.0
#
#                       batchID                      gameID  \
# 0  01J0QXP6F8GS18SVA8ZGZTQVX3  01J0QXP6FTM05EG6RC59T0XE7Q
# 1  01J0QXP6F8GS18SVA8ZGZTQVX3  01J0QXP6FR2RN1NFZB13VVKB0T
# 2  01J0QXP6F8GS18SVA8ZGZTQVX3  01J0QXP6FR2RN1NFZB13VVKB0T
#
#                      playerID                     roundID
# 0  01J0QXPJSBQXBYVH6TD639VDAH  01J0QXPN8XHFBEYZKYV53FKTKM
# 1  01J0QXX40PG85F0EQD7VYYY5W6  01J0QXX64CGBJ3ZBWVNED4QHEJ
# 2  01J0QXX40PG85F0EQD7VYYY5W6  01J0QXX64CGBJ3ZBWVNED4QHEJ

# %%
from IPython import display
display.Image("ER_diagram.png")
